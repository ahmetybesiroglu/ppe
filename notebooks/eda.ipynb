# %%
import pandas as pd

# Load the CSV file from the data directory
data_path = '../data/assets_data_mapped.csv'  # Adjust the path relative to the notebook directory
data = pd.read_csv(data_path)

# Check the first few rows of the dataset
data.head()
# Out:
#              name  asset_type_id  asset_tag impact    description  \
# 0       Dell 3520    20000254066  ASSET-668    low            NaN
# 1      MW-646TQG3    20000254066  ASSET-667    low            NaN
# 2  Macbook Pro 13    20000254066  ASSET-666    low            NaN
# 3       Dell 5520    20000254066  ASSET-665    low            NaN
# 4      MW-GC0TQG3    20000254066  ASSET-664    low  Latitude 5520
#
#    end_of_life  discovery_enabled usage_type created_by_source  \
# 0          NaN               True  permanent              User
# 1          NaN               True  permanent              User
# 2          NaN               True  permanent              User
# 3          NaN               True  permanent              User
# 4          NaN               True  permanent   Itil::ScanAgent
#
#    created_by_user  ... department_id agent_id       user_id group_id  \
# 0     2.000008e+10  ...           NaN      NaN           NaN      NaN
# ...

# %%
# Basic info about the data
data.info()

# Check for missing values
data.isnull().sum()

# Summary statistics for numeric columns
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    289 non-null    object
#  1   asset_type_id           289 non-null    int64
#  2   asset_tag               284 non-null    object
#  3   impact                  289 non-null    object
#  4   description             106 non-null    object
#  5   end_of_life             0 non-null      float64
#  6   discovery_enabled       289 non-null    bool
#  7   usage_type              289 non-null    object
#  8   created_by_source       289 non-null    object
#  9   created_by_user         273 non-null    float64
#  10  created_at              289 non-null    object
#  11  last_updated_by_source  50 non-null     object
#  12  last_updated_by_user    37 non-null     float64
#  13  updated_at              289 non-null    object
# ...

# %%
# Unique values in department_name
print("Unique departments:", data['department_name'].nunique())
print(data['department_name'].value_counts())

# Unique asset names
print("Unique asset names:", data['name'].nunique())
print(data['name'].value_counts())  # Top 10 most frequent asset names
# Out:
# Unique departments: 14
# department_name
# Unknown                   196
# Marketing                  17
# Membership Sales           16
# Art                         9
# Product                     9
# Finance                     9
# Research                    7
# Membership Coordinator      7
# Technology                  7
# Investor Support            4
# Talent Acquisition          3
# Legal                       3
# Membership Advisor          1
# Administrative              1
# Name: count, dtype: int64
# Unique asset names: 147
# name
# Dell 3520                  34
# Macbook Pro 13             29
# Macbook Pro 13"            29
# Dell Latitude 3520         16
# Macbook Pro 16"            12
#                            ..
# Appel Magic Keyboard _6     1
# Appel Magic Keyboard _7     1
# Appel Magic Keyboard _8     1
# Appel Magic Keyboard _9     1
# MW-FVFGQ4TRQ0W              1
# Name: count, Length: 147, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot for department distribution
plt.figure(figsize=(10, 6))
sns.countplot(y='department_name', data=data, order=data['department_name'].value_counts().index)
plt.title('Distribution of Assets by Department')
plt.xlabel('Number of Assets')
plt.ylabel('Department')
plt.show()

# %%
# Group by department and asset type to see the most common asset types per department
department_asset_group = data.groupby(['department_name', 'asset_type_name']).size().reset_index(name='count')

# Sort and show the top asset types in each department
department_asset_group = department_asset_group.sort_values(by='count', ascending=False)
print(department_asset_group.head(10))

# Visualization of the top asset types by department
plt.figure(figsize=(12, 8))
sns.barplot(x='count', y='department_name', hue='asset_type_name', data=department_asset_group)
plt.title('Top Asset Types by Department')
plt.xlabel('Count')
plt.ylabel('Department')
plt.legend(title='Asset Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
#            department_name asset_type_name  count
# 13                 Unknown         Unknown    196
# 5                Marketing         Unknown     17
# 8         Membership Sales         Unknown     16
# 1                     Art          Unknown      9
# 2                  Finance         Unknown      9
# 9                 Product          Unknown      9
# 7   Membership Coordinator         Unknown      7
# 10                Research         Unknown      7
# 12              Technology         Unknown      7
# 3         Investor Support         Unknown      4
